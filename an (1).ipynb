# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth your local device, follow [our guide](https://docs.unsloth.ai/get-started/install-and-update). This notebook is licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Introducing FP8 precision training for faster RL inference. [Read Blog](https://docs.unsloth.ai/new/fp8-reinforcement-learning).
#
# Unsloth's [Docker image](https://hub.docker.com/r/unsloth/unsloth) is here! Start training with no setup & environment issues. [Read our Guide](https://docs.unsloth.ai/new/how-to-train-llms-with-unsloth-and-docker).
#
# [gpt-oss RL](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning) is now supported with the fastest inference & lowest VRAM. Try our [new notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/gpt-oss-(20B)-GRPO.ipynb) which creates kernels!
#
# Introducing [Vision](https://docs.unsloth.ai/new/vision-reinforcement-learning-vlm-rl) and [Standby](https://docs.unsloth.ai/basics/memory-efficient-rl) for RL! Train Qwen, Gemma etc. VLMs with GSPO - even faster with less VRAM.
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os, re
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    import torch; v = re.match(r"[0-9]{1,}\.[0-9]{1,}", str(torch.__version__)).group(0)
    xformers = "xformers==" + ("0.0.33.post1" if v=="2.9" else "0.0.32.post2" if v=="2.8" else "0.0.29.post3")
    # !pip install --no-deps bitsandbytes accelerate {xformers} peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets==4.3.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth
# !pip install transformers==4.56.2
# !pip install --no-deps trl==0.22.2
# !pip install jiwer
# !pip install einops addict easydict

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Let's prepare the OCR model to our local first

# %%
from huggingface_hub import snapshot_download
snapshot_download("unsloth/DeepSeek-OCR", local_dir = "deepseek_ocr")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 21 files:   0%|          | 0/21 [00:00<?, ?it/s]
# README-checkpoint.md: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# assets/fig1.png:   0%|          | 0.00/396k [00:00<?, ?B/s]
# assets/show2.jpg:   0%|          | 0.00/216k [00:00<?, ?B/s]
# assets/show3.jpg:   0%|          | 0.00/247k [00:00<?, ?B/s]
# LICENSE: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# assets/show4.jpg:   0%|          | 0.00/269k [00:00<?, ?B/s]
# assets/show1.jpg:   0%|          | 0.00/117k [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# conversation.py: 0.00B [00:00, ?B/s]
# deepencoder.py: 0.00B [00:00, ?B/s]
# configuration_deepseek_v2.py: 0.00B [00:00, ?B/s]
# model-00001-of-000001.safetensors:   0%|          | 0.00/6.67G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# modeling_deepseekocr.py: 0.00B [00:00, ?B/s]
# modeling_deepseekv2.py: 0.00B [00:00, ?B/s]
# processor_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/801 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# '/content/deepseek_ocr'

# %%
from unsloth import FastVisionModel # FastLanguageModel for LLMs
import torch
from transformers import AutoModel
import os
os.environ["UNSLOTH_WARN_UNINITIALIZED"] = '0'
# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Qwen3-VL-8B-Instruct-bnb-4bit", # Qwen 3 vision support
    "unsloth/Qwen3-VL-8B-Thinking-bnb-4bit",
    "unsloth/Qwen3-VL-32B-Instruct-bnb-4bit",
    "unsloth/Qwen3-VL-32B-Thinking-bnb-4bit",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastVisionModel.from_pretrained(
    "./deepseek_ocr",
    load_in_4bit = False, # Use 4bit to reduce memory use. False for 16bit LoRA.
    auto_model = AutoModel,
    trust_remote_code=True,
    unsloth_force_compile=True,
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for long context
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# WARNING:unsloth_zoo.log:Unsloth: Failed to import trl openenv: No module named 'trl.experimental'
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2025.12.4: Fast Deepseekocr patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at ./deepseek_ocr and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Let's Evaluate Deepseek-OCR Baseline Performance on Persian Transcription

# %%
# !wget https://huggingface.co/datasets/lehoangan02/nlp/resolve/main/dataset.zip?download=true
# !unzip dataset.zip?download=true
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/images/train/243/342.jpg
#   inflating: dataset/images/train/243/343.jpg
#   inflating: dataset/images/train/243/344.jpg
#   inflating: dataset/images/train/243/345.jpg
#   inflating: dataset/images/train/243/346.jpg
#   inflating: dataset/images/train/243/347.jpg
#   inflating: dataset/images/train/243/348.jpg
#   inflating: dataset/images/train/243/349.jpg
#   inflating: dataset/images/train/243/350.jpg
#   inflating: dataset/images/train/243/351.jpg
#   inflating: dataset/images/train/243/352.jpg
#   inflating: dataset/images/train/243/353.jpg
#   inflating: dataset/images/train/243/354.jpg
#   inflating: dataset/images/train/243/355.jpg
#   inflating: dataset/images/train/243/356.jpg
#   inflating: dataset/images/train/243/357.jpg
#   inflating: dataset/images/train/243/358.jpg
#   inflating: dataset/images/train/243/360.jpg
#   inflating: dataset/images/train/243/361.jpg
#   inflating: dataset/images/train/243/362.jpg
#   inflating: dataset/images/train/243/363.jpg
#   inflating: dataset/images/train/243/364.jpg
#   inflating: dataset/images/train/243/365.jpg
#   inflating: dataset/images/train/243/366.jpg
#   inflating: dataset/images/train/243/367.jpg
#   inflating: dataset/images/train/243/368.jpg
#   inflating: dataset/images/train/243/369.jpg
#   inflating: dataset/images/train/243/370.jpg
#   inflating: dataset/images/train/243/371.jpg
#   inflating: dataset/images/train/243/372.jpg
#   inflating: dataset/images/train/243/373.jpg
#   inflating: dataset/images/train/243/374.jpg
#   inflating: dataset/images/train/243/375.jpg
#   inflating: dataset/images/train/243/376.jpg
#   inflating: dataset/images/train/243/377.jpg
#   inflating: dataset/images/train/243/378.jpg
#   inflating: dataset/images/train/243/379.jpg
#   inflating: dataset/images/train/243/380.jpg
#   inflating: dataset/images/train/243/381.jpg
#   inflating: dataset/images/train/243/382.jpg
#   inflating: dataset/images/train/243/383.jpg
#   inflating: dataset/images/train/243/384.jpg
#   inflating: dataset/images/train/243/385.jpg
#   inflating: dataset/images/train/243/386.jpg
#   inflating: dataset/images/train/243/388.jpg
#   inflating: dataset/images/train/243/389.jpg
#   inflating: dataset/images/train/243/390.jpg
#   inflating: dataset/images/train/243/392.jpg
#   inflating: dataset/images/train/243/393.jpg
#   inflating: dataset/images/train/243/394.jpg
#   inflating: dataset/images/train/243/395.jpg
#   inflating: dataset/images/train/243/396.jpg
#   inflating: dataset/images/train/243/397.jpg
#   inflating: dataset/images/train/243/398.jpg
#   inflating: dataset/images/train/243/399.jpg
#   inflating: dataset/images/train/243/400.jpg
#   inflating: dataset/images/train/243/402.jpg
#   inflating: dataset/images/train/243/403.jpg
#   inflating: dataset/images/train/243/404.jpg
#   inflating: dataset/images/train/243/405.jpg
#   inflating: dataset/images/train/243/406.jpg
#   inflating: dataset/images/train/243/407.jpg
#   inflating: dataset/images/train/243/408.jpg
#   inflating: dataset/images/train/243/409.jpg
#   inflating: dataset/images/train/243/410.jpg
#   inflating: dataset/images/train/243/411.jpg
#   inflating: dataset/images/train/243/412.jpg
#   inflating: dataset/images/train/243/413.jpg
#   inflating: dataset/images/train/243/414.jpg
#   inflating: dataset/images/train/243/415.jpg
#   inflating: dataset/images/train/243/416.jpg
#   inflating: dataset/images/train/243/417.jpg
#   inflating: dataset/images/train/243/418.jpg
#   inflating: dataset/images/train/243/419.jpg
#   inflating: dataset/images/train/243/420.jpg
#   inflating: dataset/images/train/243/421.jpg
#   inflating: dataset/images/train/243/422.jpg
#   inflating: dataset/images/train/243/423.jpg
#   inflating: dataset/images/train/243/424.jpg
#   inflating: dataset/images/train/243/425.jpg
#   inflating: dataset/images/train/243/426.jpg
#   inflating: dataset/images/train/243/427.jpg
#   inflating: dataset/images/train/243/428.jpg
#   inflating: dataset/images/train/243/429.jpg
#   inflating: dataset/images/train/243/430.jpg
#   inflating: dataset/images/train/243/431.jpg
#   inflating: dataset/images/train/243/432.jpg
#   inflating: dataset/images/train/243/433.jpg
#   inflating: dataset/images/train/243/434.jpg
#   inflating: dataset/images/train/243/435.jpg
#   inflating: dataset/images/train/243/436.jpg
#   inflating: dataset/images/train/243/437.jpg
#   inflating: dataset/images/train/243/438.jpg
#   inflating: dataset/images/train/243/439.jpg
#   inflating: dataset/images/train/243/440.jpg
#   inflating: dataset/images/train/243/441.jpg
#   inflating: dataset/images/train/243/443.jpg
#   inflating: dataset/images/train/243/444.jpg
#   inflating: dataset/images/train/243/445.jpg
#   inflating: dataset/images/train/243/446.jpg
#   inflating: dataset/images/train/243/447.jpg
#   inflating: dataset/images/train/243/448.jpg
#   inflating: dataset/images/train/243/449.jpg
#   inflating: dataset/images/train/243/450.jpg
#   inflating: dataset/images/train/243/451.jpg
#   inflating: dataset/images/train/243/452.jpg
#   inflating: dataset/images/train/243/454.jpg
#   inflating: dataset/images/train/243/455.jpg
#   inflating: dataset/images/train/243/456.jpg
#   inflating: dataset/images/train/243/457.jpg
#   inflating: dataset/images/train/243/458.jpg
#   inflating: dataset/images/train/243/459.jpg
#   inflating: dataset/images/train/243/460.jpg
#   inflating: dataset/images/train/243/461.jpg
#   inflating: dataset/images/train/243/462.jpg
#   inflating: dataset/images/train/243/463.jpg
#   inflating: dataset/images/train/243/464.jpg
#   inflating: dataset/images/train/243/465.jpg
#   inflating: dataset/images/train/243/466.jpg
#   inflating: dataset/images/train/243/467.jpg
#   inflating: dataset/images/train/243/468.jpg
#   inflating: dataset/images/train/243/469.jpg
#   inflating: dataset/images/train/243/470.jpg
#   inflating: dataset/images/train/243/471.jpg
#   inflating: dataset/images/train/243/472.jpg
#   inflating: dataset/images/train/243/473.jpg
#   inflating: dataset/images/train/243/475.jpg
#   inflating: dataset/images/train/243/476.jpg
#   inflating: dataset/images/train/243/477.jpg
#   inflating: dataset/images/train/243/478.jpg
#   inflating: dataset/images/train/243/479.jpg
#   inflating: dataset/images/train/243/480.jpg
#   inflating: dataset/images/train/243/482.jpg
#   inflating: dataset/images/train/243/483.jpg
#   inflating: dataset/images/train/243/484.jpg
#   inflating: dataset/images/train/243/485.jpg
#   inflating: dataset/images/train/243/486.jpg
#   inflating: dataset/images/train/243/487.jpg
#   inflating: dataset/images/train/243/488.jpg
#   inflating: dataset/images/train/243/489.jpg
#   inflating: dataset/images/train/243/490.jpg
#   inflating: dataset/images/train/243/491.jpg
#   inflating: dataset/images/train/243/492.jpg
#   inflating: dataset/images/train/243/493.jpg
#   inflating: dataset/images/train/243/495.jpg
#   inflating: dataset/images/train/243/496.jpg
#   inflating: dataset/images/train/243/497.jpg
#   inflating: dataset/images/train/243/499.jpg
#   inflating: dataset/images/train/243/500.jpg
#   inflating: dataset/images/train/243/501.jpg
#   inflating: dataset/images/train/243/502.jpg
#   inflating: dataset/images/train/243/503.jpg
#   inflating: dataset/images/train/243/504.jpg
#   inflating: dataset/images/train/243/505.jpg
#   inflating: dataset/images/train/243/506.jpg
#   inflating: dataset/images/train/243/507.jpg
#   inflating: dataset/images/train/243/508.jpg
#   inflating: dataset/images/train/243/509.jpg
#   inflating: dataset/images/train/243/510.jpg
#   inflating: dataset/images/train/243/511.jpg
#   inflating: dataset/images/train/243/512.jpg
#   inflating: dataset/images/train/243/514.jpg
#   inflating: dataset/images/train/243/515.jpg
#   inflating: dataset/images/train/243/516.jpg
#   inflating: dataset/images/train/243/517.jpg
#   inflating: dataset/images/train/243/518.jpg
#   inflating: dataset/images/train/243/519.jpg
#   inflating: dataset/images/train/243/520.jpg
#   inflating: dataset/images/train/243/521.jpg
#   inflating: dataset/images/train/243/522.jpg
#   inflating: dataset/images/train/243/523.jpg
#   inflating: dataset/images/train/243/524.jpg
#   inflating: dataset/images/train/243/526.jpg
#   inflating: dataset/images/train/243/527.jpg
#   inflating: dataset/images/train/243/528.jpg
#   inflating: dataset/images/train/243/529.jpg
#   inflating: dataset/images/train/243/530.jpg
#   inflating: dataset/images/train/243/531.jpg
#   inflating: dataset/images/train/243/532.jpg
#   inflating: dataset/images/train/243/533.jpg
#   inflating: dataset/images/train/243/534.jpg
#   inflating: dataset/images/train/243/535.jpg
#   inflating: dataset/images/train/243/536.jpg
#   inflating: dataset/images/train/243/537.jpg
#   inflating: dataset/images/train/243/538.jpg
#   inflating: dataset/images/train/243/539.jpg
#   inflating: dataset/images/train/243/540.jpg
#   inflating: dataset/images/train/243/541.jpg
#   inflating: dataset/images/train/243/542.jpg
#   inflating: dataset/images/train/243/543.jpg
#   inflating: dataset/images/train/243/544.jpg
#   inflating: dataset/images/train/243/545.jpg
#   inflating: dataset/images/train/243/546.jpg
#   inflating: dataset/images/train/243/547.jpg
#   inflating: dataset/images/train/243/548.jpg
#   inflating: dataset/images/train/243/551.jpg
#   inflating: dataset/images/train/243/552.jpg
#   inflating: dataset/images/train/243/553.jpg
#   inflating: dataset/images/train/243/554.jpg
#   inflating: dataset/images/train/243/555.jpg
#   inflating: dataset/images/train/243/556.jpg
#   inflating: dataset/images/train/243/557.jpg
#   inflating: dataset/images/train/243/559.jpg
#   inflating: dataset/images/train/243/560.jpg
#   inflating: dataset/images/train/243/561.jpg
#   inflating: dataset/images/train/243/562.jpg
#   inflating: dataset/images/train/243/563.jpg
#   inflating: dataset/images/train/243/564.jpg
#   inflating: dataset/images/train/243/565.jpg
#   inflating: dataset/images/train/243/566.jpg
#   inflating: dataset/images/train/243/567.jpg
#   inflating: dataset/images/train/243/568.jpg
#   inflating: dataset/images/train/243/570.jpg
#   inflating: dataset/images/train/243/571.jpg
#   inflating: dataset/images/train/243/572.jpg
#   inflating: dataset/images/train/243/574.jpg
#   inflating: dataset/images/train/243/575.jpg
#   inflating: dataset/images/train/243/576.jpg
#   inflating: dataset/images/train/243/577.jpg
#   inflating: dataset/images/train/243/578.jpg
#   inflating: dataset/images/train/243/579.jpg
#   inflating: dataset/images/train/243/580.jpg
#   inflating: dataset/images/train/243/581.jpg
#   inflating: dataset/images/train/243/582.jpg
#   inflating: dataset/images/train/243/583.jpg
#   inflating: dataset/images/train/243/584.jpg
#   inflating: dataset/images/train/243/585.jpg
#   inflating: dataset/images/train/243/586.jpg
#   inflating: dataset/images/train/243/587.jpg
#   inflating: dataset/images/train/243/588.jpg
#   inflating: dataset/images/train/243/590.jpg
#   inflating: dataset/images/train/243/591.jpg
#   inflating: dataset/images/train/243/592.jpg
#   inflating: dataset/images/train/243/593.jpg
#   inflating: dataset/images/train/243/594.jpg
#   inflating: dataset/images/train/243/595.jpg
#   inflating: dataset/images/train/243/596.jpg
#   inflating: dataset/images/train/243/597.jpg
#   inflating: dataset/images/train/243/598.jpg
#   inflating: dataset/images/train/243/599.jpg
#   inflating: dataset/images/train/243/600.jpg
#   inflating: dataset/images/train/243/601.jpg
#   inflating: dataset/images/train/243/602.jpg
#   inflating: dataset/images/train/243/603.jpg
#   inflating: dataset/images/train/243/604.jpg
#   inflating: dataset/images/train/243/606.jpg
#   inflating: dataset/images/train/243/607.jpg
#   inflating: dataset/images/train/243/610.jpg
#   inflating: dataset/images/train/243/611.jpg
#   inflating: dataset/images/train/243/612.jpg
#   inflating: dataset/images/train/243/613.jpg
#   inflating: dataset/images/train/243/614.jpg
#   inflating: dataset/images/train/243/615.jpg
#   inflating: dataset/images/train/243/616.jpg
#   inflating: dataset/images/train/243/617.jpg
#   inflating: dataset/images/train/243/618.jpg
#   inflating: dataset/images/train/243/620.jpg
#   inflating: dataset/images/train/243/621.jpg
#   inflating: dataset/images/train/243/622.jpg
#   inflating: dataset/images/train/243/623.jpg
#   inflating: dataset/images/train/243/624.jpg
#   inflating: dataset/images/train/243/625.jpg
#   inflating: dataset/images/train/243/626.jpg
#   inflating: dataset/images/train/243/627.jpg
#   inflating: dataset/images/train/243/628.jpg
#   inflating: dataset/images/train/243/629.jpg
#   inflating: dataset/images/train/243/631.jpg
#   inflating: dataset/images/train/243/632.jpg
#   inflating: dataset/images/train/243/633.jpg
#   inflating: dataset/images/train/243/634.jpg
#   inflating: dataset/images/train/243/636.jpg
#   inflating: dataset/images/train/243/637.jpg
#   inflating: dataset/images/train/243/638.jpg
#   inflating: dataset/images/train/243/639.jpg
#   inflating: dataset/images/train/243/640.jpg
#   inflating: dataset/images/train/243/641.jpg
#   inflating: dataset/images/train/243/642.jpg
#   inflating: dataset/images/train/243/643.jpg
#   inflating: dataset/images/train/243/644.jpg
#   inflating: dataset/images/train/243/645.jpg
#   inflating: dataset/images/train/243/646.jpg
#   inflating: dataset/images/train/243/647.jpg
#   inflating: dataset/images/train/243/648.jpg
#   inflating: dataset/images/train/243/649.jpg
#   inflating: dataset/images/train/243/650.jpg
#   inflating: dataset/images/train/243/652.jpg
#   inflating: dataset/images/train/243/653.jpg
#   inflating: dataset/images/train/243/654.jpg
#   inflating: dataset/images/train/243/656.jpg
#   inflating: dataset/images/train/243/657.jpg
#   inflating: dataset/images/train/243/658.jpg
#   inflating: dataset/images/train/243/660.jpg
#   inflating: dataset/images/train/243/661.jpg
#   inflating: dataset/images/train/243/662.jpg
#   inflating: dataset/images/train/243/663.jpg
#   inflating: dataset/images/train/243/664.jpg
#   inflating: dataset/images/train/243/665.jpg
#   inflating: dataset/images/train/243/666.jpg
#   inflating: dataset/images/train/243/667.jpg
#   inflating: dataset/images/train/243/668.jpg
#   inflating: dataset/images/train/243/670.jpg
#   inflating: dataset/images/train/243/671.jpg
#   inflating: dataset/images/train/243/672.jpg
#   inflating: dataset/images/train/243/673.jpg
#   inflating: dataset/images/train/243/674.jpg
#   inflating: dataset/images/train/243/675.jpg
#   inflating: dataset/images/train/243/676.jpg
#   inflating: dataset/images/train/243/677.jpg
#   inflating: dataset/images/train/243/678.jpg
#   inflating: dataset/images/train/243/679.jpg
#   inflating: dataset/images/train/243/680.jpg
#   inflating: dataset/images/train/243/681.jpg
#   inflating: dataset/images/train/243/682.jpg
#   inflating: dataset/images/train/243/684.jpg
#   inflating: dataset/images/train/243/685.jpg
#   inflating: dataset/images/train/243/686.jpg
#   inflating: dataset/images/train/243/687.jpg
#   inflating: dataset/images/train/243/688.jpg
#   inflating: dataset/images/train/243/689.jpg
#   inflating: dataset/images/train/243/690.jpg
#   inflating: dataset/images/train/243/691.jpg
#   inflating: dataset/images/train/243/692.jpg
#   inflating: dataset/images/train/243/693.jpg
#   inflating: dataset/images/train/243/694.jpg
#   inflating: dataset/images/train/243/695.jpg
#   inflating: dataset/images/train/243/696.jpg
#   inflating: dataset/images/train/243/697.jpg
#   inflating: dataset/images/train/243/699.jpg
#   inflating: dataset/images/train/243/701.jpg
#   inflating: dataset/images/train/243/703.jpg
#   inflating: dataset/images/train/243/705.jpg
#   inflating: dataset/images/train/243/706.jpg
#   inflating: dataset/images/train/243/707.jpg
#   inflating: dataset/images/train/243/708.jpg
#   inflating: dataset/images/train/243/709.jpg
#   inflating: dataset/images/train/243/710.jpg
#   inflating: dataset/images/train/243/713.jpg
#   inflating: dataset/images/train/243/714.jpg
#   inflating: dataset/images/train/243/715.jpg
#   inflating: dataset/images/train/243/716.jpg
#   inflating: dataset/images/train/243/718.jpg
#   inflating: dataset/images/train/243/719.jpg
#   inflating: dataset/images/train/243/720.jpg
#   inflating: dataset/images/train/243/721.jpg
#   inflating: dataset/images/train/243/722.jpg
#   inflating: dataset/images/train/243/723.jpg
#   inflating: dataset/images/train/243/724.jpg
#   inflating: dataset/images/train/243/725.jpg
#   inflating: dataset/images/train/243/726.jpg
#    creating: dataset/images/train/244/
#   inflating: dataset/images/train/244/1.jpg
#   inflating: dataset/images/train/244/2.jpg
#   inflating: dataset/images/train/244/3.jpg
#   inflating: dataset/images/train/244/4.jpg
#   inflating: dataset/images/train/244/5.jpg
#   inflating: dataset/images/train/244/6.jpg
#   inflating: dataset/images/train/244/7.jpg
#   inflating: dataset/images/train/244/8.jpg
#   inflating: dataset/images/train/244/10.jpg
#   inflating: dataset/images/train/244/11.jpg
#   inflating: dataset/images/train/244/12.jpg
#   inflating: dataset/images/train/244/13.jpg
#   inflating: dataset/images/train/244/15.jpg
#   inflating: dataset/images/train/244/16.jpg
#   inflating: dataset/images/train/244/17.jpg
#   inflating: dataset/images/train/244/19.jpg
#   inflating: dataset/images/train/244/20.jpg
#   inflating: dataset/images/train/244/21.jpg
#   inflating: dataset/images/train/244/22.jpg
#   inflating: dataset/images/train/244/23.jpg
#   inflating: dataset/images/train/244/24.jpg
#   inflating: dataset/images/train/244/25.jpg
#   inflating: dataset/images/train/244/26.jpg
#   inflating: dataset/images/train/244/27.jpg
#   inflating: dataset/images/train/244/28.jpg
#   inflating: dataset/images/train/244/29.jpg
#   inflating: dataset/images/train/244/30.jpg
#   inflating: dataset/images/train/244/31.jpg
#   inflating: dataset/images/train/244/32.jpg
#   inflating: dataset/images/train/244/33.jpg
#   inflating: dataset/images/train/244/34.jpg
#   inflating: dataset/images/train/244/35.jpg
#   inflating: dataset/images/train/244/36.jpg
#   inflating: dataset/images/train/244/37.jpg
#   inflating: dataset/images/train/244/38.jpg
#   inflating: dataset/images/train/244/39.jpg
#   inflating: dataset/images/train/244/40.jpg
#   inflating: dataset/images/train/244/41.jpg
#   inflating: dataset/images/train/244/42.jpg
#   inflating: dataset/images/train/244/43.jpg
#   inflating: dataset/images/train/244/44.jpg
#   inflating: dataset/images/train/244/45.jpg
#   inflating: dataset/images/train/244/46.jpg
#   inflating: dataset/images/train/244/47.jpg
#   inflating: dataset/images/train/244/49.jpg
#   inflating: dataset/images/train/244/50.jpg
#   inflating: dataset/images/train/244/51.jpg
#   inflating: dataset/images/train/244/52.jpg
#   inflating: dataset/images/train/244/53.jpg
#   inflating: dataset/images/train/244/54.jpg
#   inflating: dataset/images/train/244/55.jpg
#   inflating: dataset/images/train/244/57.jpg
#   inflating: dataset/images/train/244/58.jpg
#   inflating: dataset/images/train/244/59.jpg
#   inflating: dataset/images/train/244/60.jpg
#   inflating: dataset/images/train/244/61.jpg
#   inflating: dataset/images/train/244/62.jpg
#   inflating: dataset/images/train/244/63.jpg
#   inflating: dataset/images/train/244/64.jpg
#   inflating: dataset/images/train/244/65.jpg
#   inflating: dataset/images/train/244/66.jpg
#   inflating: dataset/images/train/244/67.jpg
#   inflating: dataset/images/train/244/68.jpg
#   inflating: dataset/images/train/244/69.jpg
#   inflating: dataset/images/train/244/70.jpg
#   inflating: dataset/images/train/244/71.jpg
#   inflating: dataset/images/train/244/72.jpg
#   inflating: dataset/images/train/244/73.jpg
#   inflating: dataset/images/train/244/74.jpg
#   inflating: dataset/images/train/244/75.jpg
#   inflating: dataset/images/train/244/76.jpg
#   inflating: dataset/images/train/244/77.jpg
#   inflating: dataset/images/train/244/78.jpg
#   inflating: dataset/images/train/244/79.jpg
#   inflating: dataset/images/train/244/80.jpg
#   inflating: dataset/images/train/244/81.jpg
#   inflating: dataset/images/train/244/82.jpg
#   inflating: dataset/images/train/244/83.jpg
#   inflating: dataset/images/train/244/84.jpg
#   inflating: dataset/images/train/244/85.jpg
#   inflating: dataset/images/train/244/86.jpg
#   inflating: dataset/images/train/244/87.jpg
#   inflating: dataset/images/train/244/88.jpg
#   inflating: dataset/images/train/244/89.jpg
#   inflating: dataset/images/train/244/90.jpg
#   inflating: dataset/images/train/244/91.jpg
#   inflating: dataset/images/train/244/92.jpg
#   inflating: dataset/images/train/244/94.jpg
#   inflating: dataset/images/train/244/95.jpg
#   inflating: dataset/images/train/244/96.jpg
#   inflating: dataset/images/train/244/97.jpg
#   inflating: dataset/images/train/244/98.jpg
#   inflating: dataset/images/train/244/99.jpg
#   inflating: dataset/images/train/244/100.jpg
#   inflating: dataset/images/train/244/101.jpg
#   inflating: dataset/images/train/244/102.jpg
#   inflating: dataset/images/train/244/103.jpg
#   inflating: dataset/images/train/244/104.jpg
#   inflating: dataset/images/train/244/105.jpg
#   inflating: dataset/images/train/244/106.jpg
#   inflating: dataset/images/train/244/107.jpg
#   inflating: dataset/images/train/244/109.jpg
#   inflating: dataset/images/train/244/110.jpg
#   inflating: dataset/images/train/244/111.jpg
#   inflating: dataset/images/train/244/112.jpg
#   inflating: dataset/images/train/244/113.jpg
#   inflating: dataset/images/train/244/114.jpg
#   inflating: dataset/images/train/244/115.jpg
#   inflating: dataset/images/train/244/116.jpg
#   inflating: dataset/images/train/244/117.jpg
#   inflating: dataset/images/train/244/118.jpg
#   inflating: dataset/images/train/244/119.jpg
#   inflating: dataset/images/train/244/120.jpg
#   inflating: dataset/images/train/244/121.jpg
#   inflating: dataset/images/train/244/122.jpg
#   inflating: dataset/images/train/244/123.jpg
#   inflating: dataset/images/train/244/124.jpg
#   inflating: dataset/images/train/244/125.jpg
#   inflating: dataset/images/train/244/126.jpg
#   inflating: dataset/images/train/244/127.jpg
#   inflating: dataset/images/train/244/128.jpg
#   inflating: dataset/images/train/244/129.jpg
#   inflating: dataset/images/train/244/131.jpg
#   inflating: dataset/images/train/244/132.jpg
#   inflating: dataset/images/train/244/133.jpg
#   inflating: dataset/images/train/244/134.jpg
#   inflating: dataset/images/train/244/135.jpg
#   inflating: dataset/images/train/244/137.jpg
#   inflating: dataset/images/train/244/138.jpg
#   inflating: dataset/images/train/244/139.jpg
#   inflating: dataset/images/train/244/140.jpg
#   inflating: dataset/images/train/244/141.jpg
#   inflating: dataset/images/train/244/142.jpg
#   inflating: dataset/images/train/244/143.jpg
#   inflating: dataset/images/train/244/144.jpg
#   inflating: dataset/images/train/244/145.jpg
#   inflating: dataset/images/train/244/146.jpg
#   inflating: dataset/images/train/244/147.jpg
#   inflating: dataset/images/train/244/148.jpg
#   inflating: dataset/images/train/244/149.jpg
#   inflating: dataset/images/train/244/150.jpg
#   inflating: dataset/images/train/244/151.jpg
#   inflating: dataset/images/train/244/152.jpg
#   inflating: dataset/images/train/244/153.jpg
#   inflating: dataset/images/train/244/154.jpg
#   inflating: dataset/images/train/244/155.jpg
#   inflating: dataset/images/train/244/156.jpg
#   inflating: dataset/images/train/244/158.jpg
#   inflating: dataset/images/train/244/160.jpg
#   inflating: dataset/images/train/244/161.jpg
#   inflating: dataset/images/train/244/162.jpg
#   inflating: dataset/images/train/244/163.jpg
#   inflating: dataset/images/train/244/164.jpg
#   inflating: dataset/images/train/244/165.jpg
#   inflating: dataset/images/train/244/166.jpg
#   inflating: dataset/images/train/244/167.jpg
#   inflating: dataset/images/train/244/168.jpg
#   inflating: dataset/images/train/244/169.jpg
#   inflating: dataset/images/train/244/170.jpg
#   inflating: dataset/images/train/244/171.jpg
#   inflating: dataset/images/train/244/172.jpg
#   inflating: dataset/images/train/244/173.jpg
#   inflating: dataset/images/train/244/174.jpg
#   inflating: dataset/images/train/244/175.jpg
#   inflating: dataset/images/train/244/176.jpg
#   inflating: dataset/images/train/244/177.jpg
#   inflating: dataset/images/train/244/178.jpg
#   inflating: dataset/images/train/244/179.jpg
#   inflating: dataset/images/train/244/180.jpg
#   inflating: dataset/images/train/244/181.jpg
#   inflating: dataset/images/train/244/182.jpg
#   inflating: dataset/images/train/244/184.jpg
#   inflating: dataset/images/train/244/185.jpg
#   inflating: dataset/images/train/244/186.jpg
#   inflating: dataset/images/train/244/187.jpg
#   inflating: dataset/images/train/244/188.jpg
#   inflating: dataset/images/train/244/189.jpg
#   inflating: dataset/images/train/244/190.jpg
#   inflating: dataset/images/train/244/191.jpg
#   inflating: dataset/images/train/244/192.jpg
#   inflating: dataset/images/train/244/193.jpg
#   inflating: dataset/images/train/244/194.jpg
#   inflating: dataset/images/train/244/195.jpg
#   inflating: dataset/images/train/244/196.jpg
#   inflating: dataset/images/train/244/197.jpg
#   inflating: dataset/images/train/244/199.jpg
#   inflating: dataset/images/train/244/200.jpg
#   inflating: dataset/images/train/244/201.jpg
#   inflating: dataset/images/train/244/202.jpg
#   inflating: dataset/images/train/244/203.jpg
#   inflating: dataset/images/train/244/204.jpg
#   inflating: dataset/images/train/244/205.jpg
#   inflating: dataset/images/train/244/206.jpg
#   inflating: dataset/images/train/244/207.jpg
#   inflating: dataset/images/train/244/208.jpg
#   inflating: dataset/images/train/244/209.jpg
#   inflating: dataset/images/train/244/210.jpg
#    creating: dataset/images/train/245/
#   inflating: dataset/images/train/245/1.jpg
#   inflating: dataset/images/train/245/2.jpg
#   inflating: dataset/images/train/245/3.jpg
#   inflating: dataset/images/train/245/4.jpg
#   inflating: dataset/images/train/245/5.jpg
#   inflating: dataset/images/train/245/6.jpg
#   inflating: dataset/images/train/245/8.jpg
#   inflating: dataset/images/train/245/9.jpg
#   inflating: dataset/images/train/245/10.jpg
#   inflating: dataset/images/train/245/11.jpg
#   inflating: dataset/images/train/245/13.jpg
#   inflating: dataset/images/train/245/14.jpg
#   inflating: dataset/images/train/245/15.jpg
#   inflating: dataset/images/train/245/16.jpg
#   inflating: dataset/images/train/245/18.jpg
#   inflating: dataset/images/train/245/19.jpg
#   inflating: dataset/images/train/245/20.jpg
#   inflating: dataset/images/train/245/21.jpg
#   inflating: dataset/images/train/245/22.jpg
#   inflating: dataset/images/train/245/23.jpg
#   inflating: dataset/images/train/245/24.jpg
#   inflating: dataset/images/train/245/25.jpg
#   inflating: dataset/images/train/245/26.jpg
#   inflating: dataset/images/train/245/27.jpg
#   inflating: dataset/images/train/245/28.jpg
#   inflating: dataset/images/train/245/29.jpg
#   inflating: dataset/images/train/245/30.jpg
#   inflating: dataset/images/train/245/31.jpg
#   inflating: dataset/images/train/245/32.jpg
#   inflating: dataset/images/train/245/34.jpg
#   inflating: dataset/images/train/245/35.jpg
#   inflating: dataset/images/train/245/36.jpg
#   inflating: dataset/images/train/245/37.jpg
#   inflating: dataset/images/train/245/38.jpg
#   inflating: dataset/images/train/245/39.jpg
#   inflating: dataset/images/train/245/41.jpg
#   inflating: dataset/images/train/245/42.jpg
#   inflating: dataset/images/train/245/43.jpg
#   inflating: dataset/images/train/245/45.jpg
#   inflating: dataset/images/train/245/46.jpg
#   inflating: dataset/images/train/245/47.jpg
#   inflating: dataset/images/train/245/48.jpg
#   inflating: dataset/images/train/245/49.jpg
#   inflating: dataset/images/train/245/50.jpg
#   inflating: dataset/images/train/245/52.jpg
#   inflating: dataset/images/train/245/53.jpg
#   inflating: dataset/images/train/245/54.jpg
#   inflating: dataset/images/train/245/55.jpg
#   inflating: dataset/images/train/245/56.jpg
#   inflating: dataset/images/train/245/58.jpg
#   inflating: dataset/images/train/245/59.jpg
#   inflating: dataset/images/train/245/60.jpg
#   inflating: dataset/images/train/245/61.jpg
#   inflating: dataset/images/train/245/62.jpg
#   inflating: dataset/images/train/245/63.jpg
#   inflating: dataset/images/train/245/64.jpg
#   inflating: dataset/images/train/245/65.jpg
#   inflating: dataset/images/train/245/66.jpg
#   inflating: dataset/images/train/245/67.jpg
#   inflating: dataset/images/train/245/68.jpg
#   inflating: dataset/images/train/245/69.jpg
#   inflating: dataset/images/train/245/70.jpg
#   inflating: dataset/images/train/245/71.jpg
#   inflating: dataset/images/train/245/72.jpg
#   inflating: dataset/images/train/245/73.jpg
#   inflating: dataset/images/train/245/74.jpg
#   inflating: dataset/images/train/245/75.jpg
#   inflating: dataset/images/train/245/76.jpg
#   inflating: dataset/images/train/245/78.jpg
#   inflating: dataset/images/train/245/79.jpg
#   inflating: dataset/images/train/245/80.jpg
#   inflating: dataset/images/train/245/81.jpg
#   inflating: dataset/images/train/245/82.jpg
#   inflating: dataset/images/train/245/83.jpg
#   inflating: dataset/images/train/245/84.jpg
#   inflating: dataset/images/train/245/85.jpg
#   inflating: dataset/images/train/245/86.jpg
#   inflating: dataset/images/train/245/88.jpg
#   inflating: dataset/images/train/245/89.jpg
#   inflating: dataset/images/train/245/90.jpg
#   inflating: dataset/images/train/245/92.jpg
#   inflating: dataset/images/train/245/93.jpg
#   inflating: dataset/images/train/245/94.jpg
#   inflating: dataset/images/train/245/95.jpg
#   inflating: dataset/images/train/245/96.jpg
#   inflating: dataset/images/train/245/97.jpg
#   inflating: dataset/images/train/245/99.jpg
#   inflating: dataset/images/train/245/101.jpg
#   inflating: dataset/images/train/245/102.jpg
#   inflating: dataset/images/train/245/103.jpg
#   inflating: dataset/images/train/245/104.jpg
#   inflating: dataset/images/train/245/105.jpg
#   inflating: dataset/images/train/245/106.jpg
#   inflating: dataset/images/train/245/107.jpg
#   inflating: dataset/images/train/245/108.jpg
#   inflating: dataset/images/train/245/109.jpg
#   inflating: dataset/images/train/245/110.jpg
#   inflating: dataset/images/train/245/111.jpg
#   inflating: dataset/images/train/245/112.jpg
#   inflating: dataset/images/train/245/113.jpg
#   inflating: dataset/images/train/245/115.jpg
#   inflating: dataset/images/train/245/116.jpg
#   inflating: dataset/images/train/245/117.jpg
#   inflating: dataset/images/train/245/118.jpg
#   inflating: dataset/images/train/245/119.jpg
#   inflating: dataset/images/train/245/120.jpg
#   inflating: dataset/images/train/245/121.jpg
#   inflating: dataset/images/train/245/122.jpg
#   inflating: dataset/images/train/245/123.jpg
#   inflating: dataset/images/train/245/125.jpg
#   inflating: dataset/images/train/245/126.jpg
#   inflating: dataset/images/train/245/127.jpg
#   inflating: dataset/images/train/245/128.jpg
#   inflating: dataset/images/train/245/129.jpg
#   inflating: dataset/images/train/245/130.jpg
#   inflating: dataset/images/train/245/131.jpg
#   inflating: dataset/images/train/245/132.jpg
#   inflating: dataset/images/train/245/133.jpg
#   inflating: dataset/images/train/245/134.jpg
#   inflating: dataset/images/train/245/135.jpg
#   inflating: dataset/images/train/245/136.jpg
#   inflating: dataset/images/train/245/137.jpg
#   inflating: dataset/images/train/245/138.jpg
#   inflating: dataset/images/train/245/140.jpg
#   inflating: dataset/images/train/245/141.jpg
#   inflating: dataset/images/train/245/142.jpg
#   inflating: dataset/images/train/245/144.jpg
#   inflating: dataset/images/train/245/145.jpg
#   inflating: dataset/images/train/245/146.jpg
#   inflating: dataset/images/train/245/147.jpg
#   inflating: dataset/images/train/245/148.jpg
#   inflating: dataset/images/train/245/149.jpg
#   inflating: dataset/images/train/245/150.jpg
#   inflating: dataset/images/train/245/151.jpg
#   inflating: dataset/images/train/245/152.jpg
#   inflating: dataset/images/train/245/153.jpg
#   inflating: dataset/images/train/245/154.jpg
#   inflating: dataset/images/train/245/155.jpg
#   inflating: dataset/images/train/245/156.jpg
#   inflating: dataset/images/train/245/157.jpg
#   inflating: dataset/images/train/245/158.jpg
#   inflating: dataset/images/train/245/159.jpg
#   inflating: dataset/images/train/245/160.jpg
#   inflating: dataset/images/train/245/161.jpg
#   inflating: dataset/images/train/245/162.jpg
#   inflating: dataset/images/train/245/163.jpg
#   inflating: dataset/images/train/245/164.jpg
#   inflating: dataset/images/train/245/165.jpg
#   inflating: dataset/images/train/245/166.jpg
#   inflating: dataset/images/train/245/168.jpg
#   inflating: dataset/images/train/245/169.jpg
#   inflating: dataset/images/train/245/170.jpg
#   inflating: dataset/images/train/245/171.jpg
#   inflating: dataset/images/train/245/172.jpg
#   inflating: dataset/images/train/245/173.jpg
#   inflating: dataset/images/train/245/174.jpg
#   inflating: dataset/images/train/245/175.jpg
#   inflating: dataset/images/train/245/176.jpg
#   inflating: dataset/images/train/245/177.jpg
#   inflating: dataset/images/train/245/178.jpg
#   inflating: dataset/images/train/245/179.jpg
#   inflating: dataset/images/train/245/180.jpg
#   inflating: dataset/images/train/245/181.jpg
#   inflating: dataset/images/train/245/182.jpg
#   inflating: dataset/images/train/245/183.jpg
#   inflating: dataset/images/train/245/184.jpg
#   inflating: dataset/images/train/245/185.jpg
#   inflating: dataset/images/train/245/186.jpg
#   inflating: dataset/images/train/245/188.jpg
#   inflating: dataset/images/train/245/189.jpg
#   inflating: dataset/images/train/245/190.jpg
#   inflating: dataset/images/train/245/191.jpg
#   inflating: dataset/images/train/245/192.jpg
#   inflating: dataset/images/train/245/193.jpg
#   inflating: dataset/images/train/245/194.jpg
#   inflating: dataset/images/train/245/195.jpg
#   inflating: dataset/images/train/245/196.jpg
#   inflating: dataset/images/train/245/197.jpg
#   inflating: dataset/images/train/245/198.jpg
#   inflating: dataset/images/train/245/199.jpg
#   inflating: dataset/images/train/245/200.jpg
#   inflating: dataset/images/train/245/201.jpg
#   inflating: dataset/images/train/245/202.jpg
#   inflating: dataset/images/train/245/203.jpg
#   inflating: dataset/images/train/245/204.jpg
#   inflating: dataset/images/train/245/205.jpg
#   inflating: dataset/images/train/245/206.jpg
#   inflating: dataset/images/train/245/207.jpg
#   inflating: dataset/images/train/245/209.jpg
#   inflating: dataset/images/train/245/210.jpg
#   inflating: dataset/images/train/245/211.jpg
#   inflating: dataset/images/train/245/212.jpg
#   inflating: dataset/images/train/245/213.jpg
#   inflating: dataset/images/train/245/214.jpg
#   inflating: dataset/images/train/245/215.jpg
#   inflating: dataset/images/train/245/216.jpg
#   inflating: dataset/images/train/245/217.jpg
#   inflating: dataset/images/train/245/218.jpg
#   inflating: dataset/images/train/245/219.jpg
#   inflating: dataset/images/train/245/220.jpg
#   inflating: dataset/images/train/245/221.jpg
#   inflating: dataset/images/train/245/222.jpg
#   inflating: dataset/images/train/245/223.jpg
#   inflating: dataset/images/train/245/224.jpg
#   inflating: dataset/images/train/245/225.jpg
#   inflating: dataset/images/train/245/226.jpg
#   inflating: dataset/images/train/245/227.jpg
#   inflating: dataset/images/train/245/228.jpg
#   inflating: dataset/images/train/245/229.jpg
#   inflating: dataset/images/train/245/230.jpg
#   inflating: dataset/images/train/245/231.jpg
#   inflating: dataset/images/train/245/232.jpg
#   inflating: dataset/images/train/245/233.jpg
#   inflating: dataset/images/train/245/234.jpg
#   inflating: dataset/images/train/245/235.jpg
#   inflating: dataset/images/train/245/236.jpg
#   inflating: dataset/images/train/245/237.jpg
#   inflating: dataset/images/train/245/238.jpg
#   inflating: dataset/images/train/245/239.jpg
#   inflating: dataset/images/train/245/240.jpg
#   inflating: dataset/images/train/245/241.jpg
#   inflating: dataset/images/train/245/242.jpg
#   inflating: dataset/images/train/245/245.jpg
#   inflating: dataset/images/train/245/246.jpg
#   inflating: dataset/images/train/245/247.jpg
#   inflating: dataset/images/train/245/248.jpg
#   inflating: dataset/images/train/245/249.jpg
#   inflating: dataset/images/train/245/250.jpg
#   inflating: dataset/images/train/245/251.jpg
#   inflating: dataset/images/train/245/252.jpg
#   inflating: dataset/images/train/245/253.jpg
#   inflating: dataset/images/train/245/254.jpg
#   inflating: dataset/images/train/245/256.jpg
#   inflating: dataset/images/train/245/257.jpg
#   inflating: dataset/images/train/245/258.jpg
#   inflating: dataset/images/train/245/259.jpg
#   inflating: dataset/images/train/245/260.jpg
#   inflating: dataset/images/train/245/261.jpg
#   inflating: dataset/images/train/245/262.jpg
#   inflating: dataset/images/train/245/263.jpg
#   inflating: dataset/images/train/245/264.jpg
#   inflating: dataset/images/train/245/265.jpg
#   inflating: dataset/images/train/245/266.jpg
#   inflating: dataset/images/train/245/267.jpg
#   inflating: dataset/images/train/245/268.jpg
#   inflating: dataset/images/train/245/269.jpg
#   inflating: dataset/images/train/245/270.jpg
#   inflating: dataset/images/train/245/271.jpg
#   inflating: dataset/images/train/245/272.jpg
#   inflating: dataset/images/train/245/273.jpg
#   inflating: dataset/images/train/245/274.jpg
#   inflating: dataset/images/train/245/275.jpg
#   inflating: dataset/images/train/245/276.jpg
#   inflating: dataset/images/train/245/277.jpg
#   inflating: dataset/images/train/245/278.jpg
#   inflating: dataset/images/train/245/279.jpg
#   inflating: dataset/images/train/245/280.jpg
#   inflating: dataset/images/train/245/281.jpg
#   inflating: dataset/images/train/245/282.jpg
#   inflating: dataset/images/train/245/283.jpg
#   inflating: dataset/images/train/245/284.jpg
#   inflating: dataset/images/train/245/285.jpg
#   inflating: dataset/images/train/245/286.jpg
#   inflating: dataset/images/train/245/287.jpg
#   inflating: dataset/images/train/245/288.jpg
#   inflating: dataset/images/train/245/290.jpg
#   inflating: dataset/images/train/245/291.jpg
#   inflating: dataset/images/train/245/292.jpg
#   inflating: dataset/images/train/245/293.jpg
#   inflating: dataset/images/train/245/295.jpg
#   inflating: dataset/images/train/245/297.jpg
#   inflating: dataset/images/train/245/298.jpg
#   inflating: dataset/images/train/245/300.jpg
#   inflating: dataset/images/train/245/301.jpg
#   inflating: dataset/images/train/245/302.jpg
#   inflating: dataset/images/train/245/304.jpg
#   inflating: dataset/images/train/245/305.jpg
#   inflating: dataset/images/train/245/307.jpg
#   inflating: dataset/images/train/245/308.jpg
#   inflating: dataset/images/train/245/309.jpg
#   inflating: dataset/images/train/245/310.jpg
#   inflating: dataset/images/train/245/311.jpg
#   inflating: dataset/images/train/245/312.jpg
#   inflating: dataset/images/train/245/313.jpg
#   inflating: dataset/images/train/245/314.jpg
#   inflating: dataset/images/train/245/315.jpg
#   inflating: dataset/images/train/245/316.jpg
#   inflating: dataset/images/train/245/317.jpg
#   inflating: dataset/images/train/245/318.jpg
#   inflating: dataset/images/train/245/319.jpg
#   inflating: dataset/images/train/245/320.jpg
#   inflating: dataset/images/train/245/321.jpg
#   inflating: dataset/images/train/245/322.jpg
#   inflating: dataset/images/train/245/323.jpg
#   inflating: dataset/images/train/245/324.jpg
#   inflating: dataset/images/train/245/325.jpg
#   inflating: dataset/images/train/245/326.jpg
#   inflating: dataset/images/train/245/328.jpg
#   inflating: dataset/images/train/245/329.jpg
#   inflating: dataset/images/train/245/330.jpg
#   inflating: dataset/images/train/245/331.jpg
#   inflating: dataset/images/train/245/332.jpg
#   inflating: dataset/images/train/245/333.jpg
#   inflating: dataset/images/train/245/335.jpg
#   inflating: dataset/images/train/245/336.jpg
#   inflating: dataset/images/train/245/337.jpg
#   inflating: dataset/images/train/245/338.jpg
#   inflating: dataset/images/train/245/339.jpg
#   inflating: dataset/images/train/245/340.jpg
#   inflating: dataset/images/train/245/342.jpg
#   inflating: dataset/images/train/245/343.jpg
#   inflating: dataset/images/train/245/344.jpg
#   inflating: dataset/images/train/245/345.jpg
#   inflating: dataset/images/train/245/346.jpg
#   inflating: dataset/images/train/245/347.jpg
#   inflating: dataset/images/train/245/348.jpg
#   inflating: dataset/images/train/245/349.jpg
#   inflating: dataset/images/train/245/350.jpg
#   inflating: dataset/images/train/245/351.jpg
#   inflating: dataset/images/train/245/352.jpg
#   inflating: dataset/images/train/245/353.jpg
#   inflating: dataset/images/train/245/355.jpg
#   inflating: dataset/images/train/245/356.jpg
#   inflating: dataset/images/train/245/357.jpg
#   inflating: dataset/images/train/245/358.jpg
#   inflating: dataset/images/train/245/360.jpg
#   inflating: dataset/images/train/245/361.jpg
#   inflating: dataset/images/train/245/362.jpg
#   inflating: dataset/images/train/245/363.jpg
#   inflating: dataset/images/train/245/364.jpg
#   inflating: dataset/images/train/245/365.jpg
#   inflating: dataset/images/train/245/366.jpg
#   inflating: dataset/images/train/245/367.jpg
#   inflating: dataset/images/train/245/368.jpg
#   inflating: dataset/images/train/245/369.jpg
#   inflating: dataset/images/train/245/370.jpg
#   inflating: dataset/images/train/245/371.jpg
#   inflating: dataset/images/train/245/372.jpg
#   inflating: dataset/images/train/245/373.jpg
#   inflating: dataset/images/train/245/374.jpg
#   inflating: dataset/images/train/245/375.jpg
#   inflating: dataset/images/train/245/377.jpg
#   inflating: dataset/images/train/245/379.jpg
#   inflating: dataset/images/train/245/380.jpg
#   inflating: dataset/images/train/245/381.jpg
#   inflating: dataset/images/train/245/382.jpg
#   inflating: dataset/images/train/245/383.jpg
#   inflating: dataset/images/train/245/384.jpg
#   inflating: dataset/images/train/245/385.jpg
#   inflating: dataset/images/train/245/386.jpg
#   inflating: dataset/images/train/245/387.jpg
#   inflating: dataset/images/train/245/388.jpg
#   inflating: dataset/images/train/245/389.jpg
#   inflating: dataset/images/train/245/390.jpg
#   inflating: dataset/images/train/245/391.jpg
#   inflating: dataset/images/train/245/392.jpg
#   inflating: dataset/images/train/245/393.jpg
#   inflating: dataset/images/train/245/394.jpg
#   inflating: dataset/images/train/245/395.jpg
#   inflating: dataset/images/train/245/396.jpg
#   inflating: dataset/images/train/245/397.jpg
#   inflating: dataset/images/train/245/398.jpg
#   inflating: dataset/images/train/245/399.jpg
#   inflating: dataset/images/train/245/400.jpg
#   inflating: dataset/images/train/245/402.jpg
#    creating: dataset/images/train/246/
#   inflating: dataset/images/train/246/1.jpg
#   inflating: dataset/images/train/246/2.jpg
#   inflating: dataset/images/train/246/3.jpg
#   inflating: dataset/images/train/246/4.jpg
#   inflating: dataset/images/train/246/5.jpg
#   inflating: dataset/images/train/246/6.jpg
#   inflating: dataset/images/train/246/7.jpg
#   inflating: dataset/images/train/246/8.jpg
#   inflating: dataset/images/train/246/9.jpg
#   inflating: dataset/images/train/246/10.jpg
#   inflating: dataset/images/train/246/11.jpg
#   inflating: dataset/images/train/246/12.jpg
#   inflating: dataset/images/train/246/13.jpg
#   inflating: dataset/images/train/246/14.jpg
#   inflating: dataset/images/train/246/15.jpg
#   inflating: dataset/images/train/246/16.jpg
#   inflating: dataset/images/train/246/17.jpg
#   inflating: dataset/images/train/246/18.jpg
#   inflating: dataset/images/train/246/19.jpg
#   inflating: dataset/images/train/246/20.jpg
#   inflating: dataset/images/train/246/21.jpg
#   inflating: dataset/images/train/246/22.jpg
#   inflating: dataset/images/train/246/23.jpg
#   inflating: dataset/images/train/246/24.jpg
#   inflating: dataset/images/train/246/25.jpg
#   inflating: dataset/images/train/246/26.jpg
#   inflating: dataset/images/train/246/27.jpg
#   inflating: dataset/images/train/246/29.jpg
#   inflating: dataset/images/train/246/30.jpg
#   inflating: dataset/images/train/246/31.jpg
#   inflating: dataset/images/train/246/32.jpg
#   inflating: dataset/images/train/246/34.jpg
#   inflating: dataset/images/train/246/35.jpg
#   inflating: dataset/images/train/246/36.jpg
#   inflating: dataset/images/train/246/37.jpg
#   inflating: dataset/images/train/246/38.jpg
#   inflating: dataset/images/train/246/39.jpg
#   inflating: dataset/images/train/246/40.jpg
#   inflating: dataset/images/train/246/41.jpg
#   inflating: dataset/images/train/246/42.jpg
#   inflating: dataset/images/train/246/43.jpg
#   inflating: dataset/images/train/246/44.jpg
#   inflating: dataset/images/train/246/45.jpg
#   inflating: dataset/images/train/246/46.jpg
#   inflating: dataset/images/train/246/47.jpg
#   inflating: dataset/images/train/246/48.jpg
#   inflating: dataset/images/train/246/49.jpg
#   inflating: dataset/images/train/246/50.jpg
#   inflating: dataset/images/train/246/51.jpg
#   inflating: dataset/images/train/246/52.jpg
#   inflating: dataset/images/train/246/53.jpg
#   inflating: dataset/images/train/246/54.jpg
#   inflating: dataset/images/train/246/55.jpg
#   inflating: dataset/images/train/246/56.jpg
#   inflating: dataset/images/train/246/57.jpg
#   inflating: dataset/images/train/246/58.jpg
#   inflating: dataset/images/train/246/59.jpg
#   inflating: dataset/images/train/246/61.jpg
#   inflating: dataset/images/train/246/62.jpg
#   inflating: dataset/images/train/246/63.jpg
#   inflating: dataset/images/train/246/64.jpg
#   inflating: dataset/images/train/246/65.jpg
#   inflating: dataset/images/train/246/66.jpg
#   inflating: dataset/images/train/246/67.jpg
#   inflating: dataset/images/train/246/68.jpg
#   inflating: dataset/images/train/246/69.jpg
#   inflating: dataset/images/train/246/70.jpg
#   inflating: dataset/images/train/246/71.jpg
#   inflating: dataset/images/train/246/72.jpg
#   inflating: dataset/images/train/246/73.jpg
#   inflating: dataset/images/train/246/74.jpg
#   inflating: dataset/images/train/246/75.jpg
#   inflating: dataset/images/train/246/76.jpg
#   inflating: dataset/images/train/246/77.jpg
#   inflating: dataset/images/train/246/78.jpg
#   inflating: dataset/images/train/246/79.jpg
#   inflating: dataset/images/train/246/80.jpg
#   inflating: dataset/images/train/246/81.jpg
#   inflating: dataset/images/train/246/82.jpg
#   inflating: dataset/images/train/246/83.jpg
#   inflating: dataset/images/train/246/84.jpg
#   inflating: dataset/images/train/246/85.jpg
#   inflating: dataset/images/train/246/86.jpg
#   inflating: dataset/images/train/246/87.jpg
#   inflating: dataset/images/train/246/88.jpg
#   inflating: dataset/images/train/246/89.jpg
#   inflating: dataset/images/train/246/90.jpg
#   inflating: dataset/images/train/246/91.jpg
#   inflating: dataset/images/train/246/93.jpg
#   inflating: dataset/images/train/246/94.jpg
#   inflating: dataset/images/train/246/95.jpg
# ...
#   inflating: dataset/images/test/255/71.jpg
#   inflating: dataset/images/test/255/72.jpg
#   inflating: dataset/images/test/255/73.jpg
#   inflating: dataset/images/test/255/74.jpg
#   inflating: dataset/images/test/255/75.jpg
#   inflating: dataset/images/test/255/76.jpg
#   inflating: dataset/images/test/255/77.jpg
#   inflating: dataset/images/test/255/78.jpg
#   inflating: dataset/images/test/255/79.jpg
#   inflating: dataset/images/test/255/80.jpg
#   inflating: dataset/images/test/255/81.jpg
#   inflating: dataset/images/test/255/82.jpg
#   inflating: dataset/images/test/255/83.jpg
#   inflating: dataset/images/test/255/84.jpg
#   inflating: dataset/images/test/255/85.jpg
#   inflating: dataset/images/test/255/86.jpg
#   inflating: dataset/images/test/255/87.jpg
#   inflating: dataset/images/test/255/88.jpg
#   inflating: dataset/images/test/255/89.jpg
#   inflating: dataset/images/test/255/90.jpg
#   inflating: dataset/images/test/255/91.jpg
#   inflating: dataset/images/test/255/92.jpg
#   inflating: dataset/images/test/255/93.jpg
#   inflating: dataset/images/test/255/94.jpg
#   inflating: dataset/images/test/255/95.jpg
#   inflating: dataset/images/test/255/96.jpg
#   inflating: dataset/images/test/255/97.jpg
#   inflating: dataset/images/test/255/98.jpg
#   inflating: dataset/images/test/255/99.jpg
#   inflating: dataset/images/test/255/100.jpg
#   inflating: dataset/images/test/255/101.jpg
#   inflating: dataset/images/test/255/102.jpg
#   inflating: dataset/images/test/255/103.jpg
#   inflating: dataset/images/test/255/104.jpg
#   inflating: dataset/images/test/255/105.jpg
#   inflating: dataset/images/test/255/106.jpg
#   inflating: dataset/images/test/255/107.jpg
#   inflating: dataset/images/test/255/108.jpg
#   inflating: dataset/images/test/255/109.jpg
#   inflating: dataset/images/test/255/110.jpg
#   inflating: dataset/images/test/255/111.jpg
#   inflating: dataset/images/test/255/112.jpg
#   inflating: dataset/images/test/255/113.jpg
#   inflating: dataset/images/test/255/114.jpg
#   inflating: dataset/images/test/255/115.jpg
#   inflating: dataset/images/test/255/116.jpg
#   inflating: dataset/images/test/255/117.jpg
#   inflating: dataset/images/test/255/118.jpg
#   inflating: dataset/images/test/255/119.jpg
#   inflating: dataset/images/test/255/120.jpg
#   inflating: dataset/images/test/255/121.jpg
#   inflating: dataset/images/test/255/122.jpg
#   inflating: dataset/images/test/255/123.jpg
#   inflating: dataset/images/test/255/124.jpg
#   inflating: dataset/images/test/255/125.jpg
#   inflating: dataset/images/test/255/126.jpg
#   inflating: dataset/images/test/255/127.jpg
#   inflating: dataset/images/test/255/128.jpg
#   inflating: dataset/images/test/255/129.jpg
#   inflating: dataset/images/test/255/130.jpg
#   inflating: dataset/images/test/255/131.jpg
#   inflating: dataset/images/test/255/132.jpg
#   inflating: dataset/images/test/255/133.jpg
#   inflating: dataset/images/test/255/134.jpg
#   inflating: dataset/images/test/255/135.jpg
#   inflating: dataset/images/test/255/136.jpg
#   inflating: dataset/images/test/255/137.jpg
#   inflating: dataset/images/test/255/138.jpg
#   inflating: dataset/images/test/255/139.jpg
#   inflating: dataset/images/test/255/140.jpg
#   inflating: dataset/images/test/255/141.jpg
#   inflating: dataset/images/test/255/142.jpg
#   inflating: dataset/images/test/255/143.jpg
#   inflating: dataset/images/test/255/144.jpg
#   inflating: dataset/images/test/255/145.jpg
#   inflating: dataset/images/test/255/146.jpg
#   inflating: dataset/images/test/255/147.jpg
#   inflating: dataset/images/test/255/148.jpg
#   inflating: dataset/images/test/255/149.jpg
#   inflating: dataset/images/test/255/150.jpg
#   inflating: dataset/images/test/255/151.jpg
#   inflating: dataset/images/test/255/152.jpg
#   inflating: dataset/images/test/255/153.jpg
#   inflating: dataset/images/test/255/154.jpg
#   inflating: dataset/images/test/255/155.jpg
#   inflating: dataset/images/test/255/156.jpg
#   inflating: dataset/images/test/255/157.jpg
#   inflating: dataset/images/test/255/158.jpg
#   inflating: dataset/images/test/255/159.jpg
#   inflating: dataset/images/test/255/160.jpg
#   inflating: dataset/images/test/255/161.jpg
#   inflating: dataset/images/test/255/162.jpg
#   inflating: dataset/images/test/255/163.jpg
#   inflating: dataset/images/test/255/164.jpg
#   inflating: dataset/images/test/255/165.jpg
#   inflating: dataset/images/test/255/166.jpg
#   inflating: dataset/images/test/255/167.jpg
#   inflating: dataset/images/test/255/168.jpg
#   inflating: dataset/images/test/255/169.jpg
#   inflating: dataset/images/test/255/170.jpg
#   inflating: dataset/images/test/255/171.jpg
#   inflating: dataset/images/test/255/172.jpg
#   inflating: dataset/images/test/255/173.jpg
#   inflating: dataset/images/test/255/174.jpg
#   inflating: dataset/images/test/255/175.jpg
#   inflating: dataset/images/test/255/176.jpg
#   inflating: dataset/images/test/255/177.jpg
#   inflating: dataset/images/test/255/178.jpg
#   inflating: dataset/images/test/255/179.jpg
#   inflating: dataset/images/test/255/180.jpg
#   inflating: dataset/images/test/255/181.jpg
#   inflating: dataset/images/test/255/182.jpg
#   inflating: dataset/images/test/255/183.jpg
#   inflating: dataset/images/test/255/184.jpg
#   inflating: dataset/images/test/255/185.jpg
#   inflating: dataset/images/test/255/186.jpg
#   inflating: dataset/images/test/255/187.jpg
#   inflating: dataset/images/test/255/188.jpg
#   inflating: dataset/images/test/255/189.jpg
#   inflating: dataset/images/test/255/190.jpg
#   inflating: dataset/images/test/255/191.jpg
#   inflating: dataset/images/test/255/192.jpg
#   inflating: dataset/images/test/255/193.jpg
#   inflating: dataset/images/test/255/194.jpg
#   inflating: dataset/images/test/255/195.jpg
#   inflating: dataset/images/test/255/196.jpg
#   inflating: dataset/images/test/255/197.jpg
#   inflating: dataset/images/test/255/198.jpg
#   inflating: dataset/images/test/255/199.jpg
#   inflating: dataset/images/test/255/200.jpg
#   inflating: dataset/images/test/255/201.jpg
#   inflating: dataset/images/test/255/202.jpg
#   inflating: dataset/images/test/255/203.jpg
#   inflating: dataset/images/test/255/204.jpg
#   inflating: dataset/images/test/255/205.jpg
#   inflating: dataset/images/test/255/206.jpg
#   inflating: dataset/images/test/255/207.jpg
#   inflating: dataset/images/test/255/208.jpg
#   inflating: dataset/images/test/255/209.jpg
#   inflating: dataset/images/test/255/210.jpg
#   inflating: dataset/images/test/255/211.jpg
#   inflating: dataset/images/test/255/212.jpg
#   inflating: dataset/images/test/255/213.jpg
#   inflating: dataset/images/test/255/214.jpg
#   inflating: dataset/images/test/255/215.jpg
#   inflating: dataset/images/test/255/216.jpg
#   inflating: dataset/images/test/255/217.jpg
#   inflating: dataset/images/test/255/218.jpg
#   inflating: dataset/images/test/255/219.jpg
#   inflating: dataset/images/test/255/220.jpg
#   inflating: dataset/images/test/255/221.jpg
#   inflating: dataset/images/test/255/222.jpg
#   inflating: dataset/images/test/255/223.jpg
#   inflating: dataset/images/test/255/224.jpg
#   inflating: dataset/images/test/255/225.jpg
#   inflating: dataset/images/test/255/226.jpg
#   inflating: dataset/images/test/255/227.jpg
#   inflating: dataset/images/test/255/228.jpg
#   inflating: dataset/images/test/255/229.jpg
#   inflating: dataset/images/test/255/230.jpg
#   inflating: dataset/images/test/255/231.jpg
#   inflating: dataset/images/test/255/232.jpg
#   inflating: dataset/images/test/255/233.jpg
#   inflating: dataset/images/test/255/234.jpg
#   inflating: dataset/images/test/255/235.jpg
#   inflating: dataset/images/test/255/236.jpg
#   inflating: dataset/images/test/255/237.jpg
#   inflating: dataset/images/test/255/238.jpg
#   inflating: dataset/images/test/255/239.jpg
#   inflating: dataset/images/test/255/240.jpg
#   inflating: dataset/images/test/255/241.jpg
#   inflating: dataset/images/test/255/242.jpg
#   inflating: dataset/images/test/255/243.jpg
#   inflating: dataset/images/test/255/244.jpg
#   inflating: dataset/images/test/255/245.jpg
#   inflating: dataset/images/test/255/246.jpg
#   inflating: dataset/images/test/255/247.jpg
#   inflating: dataset/images/test/255/248.jpg
#   inflating: dataset/images/test/255/249.jpg
#   inflating: dataset/images/test/255/250.jpg
#   inflating: dataset/images/test/255/251.jpg
#   inflating: dataset/images/test/255/252.jpg
#   inflating: dataset/images/test/255/253.jpg
#   inflating: dataset/images/test/255/254.jpg
#   inflating: dataset/images/test/255/255.jpg
#   inflating: dataset/images/test/255/256.jpg
#   inflating: dataset/images/test/255/257.jpg
#   inflating: dataset/images/test/255/258.jpg
#   inflating: dataset/images/test/255/259.jpg
#   inflating: dataset/images/test/255/260.jpg
#   inflating: dataset/images/test/255/261.jpg
#   inflating: dataset/images/test/255/262.jpg
#   inflating: dataset/images/test/255/263.jpg
#   inflating: dataset/images/test/255/264.jpg
#   inflating: dataset/images/test/255/265.jpg
#   inflating: dataset/images/test/255/266.jpg
#   inflating: dataset/images/test/255/267.jpg
#   inflating: dataset/images/test/255/268.jpg
#   inflating: dataset/images/test/255/269.jpg
#   inflating: dataset/images/test/255/270.jpg
#   inflating: dataset/images/test/255/271.jpg
#   inflating: dataset/images/test/255/272.jpg
#   inflating: dataset/images/test/255/273.jpg
#   inflating: dataset/images/test/255/274.jpg
#   inflating: dataset/images/test/255/275.jpg
#   inflating: dataset/images/test/255/276.jpg
#   inflating: dataset/images/test/255/277.jpg
#   inflating: dataset/images/test/255/278.jpg
#   inflating: dataset/images/test/255/279.jpg
#   inflating: dataset/images/test/255/280.jpg
#   inflating: dataset/images/test/255/281.jpg
#   inflating: dataset/images/test/255/282.jpg
#   inflating: dataset/images/test/255/283.jpg
#   inflating: dataset/images/test/255/284.jpg
#   inflating: dataset/images/test/255/285.jpg
#   inflating: dataset/images/test/255/286.jpg
#   inflating: dataset/images/test/255/287.jpg
#   inflating: dataset/images/test/255/288.jpg
#   inflating: dataset/images/test/255/289.jpg
#   inflating: dataset/images/test/255/290.jpg
#   inflating: dataset/images/test/255/291.jpg
#   inflating: dataset/images/test/255/292.jpg
#   inflating: dataset/images/test/255/293.jpg
#   inflating: dataset/images/test/255/294.jpg
#   inflating: dataset/images/test/255/295.jpg
#   inflating: dataset/images/test/255/296.jpg
#   inflating: dataset/images/test/255/297.jpg
#   inflating: dataset/images/test/255/298.jpg
#   inflating: dataset/images/test/255/299.jpg
#   inflating: dataset/images/test/255/300.jpg
#   inflating: dataset/images/test/255/301.jpg
#   inflating: dataset/images/test/255/302.jpg
#   inflating: dataset/images/test/255/303.jpg
#   inflating: dataset/images/test/255/304.jpg
#   inflating: dataset/images/test/255/305.jpg
#   inflating: dataset/images/test/255/306.jpg
#   inflating: dataset/images/test/255/307.jpg
#   inflating: dataset/images/test/255/308.jpg
#   inflating: dataset/images/test/255/309.jpg
#   inflating: dataset/images/test/255/310.jpg
#   inflating: dataset/images/test/255/311.jpg
#   inflating: dataset/images/test/255/312.jpg
#   inflating: dataset/images/test/255/313.jpg
#   inflating: dataset/images/test/255/314.jpg
#   inflating: dataset/images/test/255/315.jpg
#   inflating: dataset/images/test/255/316.jpg
#   inflating: dataset/images/test/255/317.jpg
#   inflating: dataset/images/test/255/318.jpg
#   inflating: dataset/images/test/255/319.jpg
#   inflating: dataset/images/test/255/320.jpg
#   inflating: dataset/images/test/255/321.jpg
#   inflating: dataset/images/test/255/322.jpg
#   inflating: dataset/images/test/255/323.jpg
#   inflating: dataset/images/test/255/324.jpg
#   inflating: dataset/images/test/255/325.jpg
#   inflating: dataset/images/test/255/326.jpg
#   inflating: dataset/images/test/255/327.jpg
#   inflating: dataset/images/test/255/328.jpg
#   inflating: dataset/images/test/255/329.jpg
#   inflating: dataset/images/test/255/330.jpg
#   inflating: dataset/images/test/255/331.jpg
#   inflating: dataset/images/test/255/332.jpg
#   inflating: dataset/images/test/255/333.jpg
#   inflating: dataset/images/test/255/334.jpg
#   inflating: dataset/images/test/255/335.jpg
#   inflating: dataset/images/test/255/336.jpg
#   inflating: dataset/images/test/255/337.jpg
#   inflating: dataset/images/test/255/338.jpg
#   inflating: dataset/images/test/255/339.jpg
#   inflating: dataset/images/test/255/340.jpg
#   inflating: dataset/images/test/255/341.jpg
#   inflating: dataset/images/test/255/342.jpg
#   inflating: dataset/images/test/255/343.jpg
#   inflating: dataset/images/test/255/344.jpg
#   inflating: dataset/images/test/255/345.jpg
#   inflating: dataset/images/test/255/346.jpg
#   inflating: dataset/images/test/255/347.jpg
#   inflating: dataset/images/test/255/348.jpg
#   inflating: dataset/images/test/255/349.jpg
#   inflating: dataset/images/test/255/350.jpg
#   inflating: dataset/images/test/255/351.jpg
#   inflating: dataset/images/test/255/352.jpg
#   inflating: dataset/images/test/255/353.jpg
#   inflating: dataset/images/test/255/354.jpg
#   inflating: dataset/images/test/255/355.jpg
#   inflating: dataset/images/test/255/356.jpg
#   inflating: dataset/images/test/255/357.jpg
#   inflating: dataset/images/test/255/358.jpg
#   inflating: dataset/images/test/255/359.jpg
#   inflating: dataset/images/test/255/360.jpg
#   inflating: dataset/images/test/255/361.jpg
#   inflating: dataset/images/test/255/362.jpg
#   inflating: dataset/images/test/255/363.jpg
#   inflating: dataset/images/test/255/364.jpg
#   inflating: dataset/images/test/255/365.jpg
#   inflating: dataset/images/test/255/366.jpg
#   inflating: dataset/images/test/255/367.jpg
#   inflating: dataset/images/test/255/368.jpg
#   inflating: dataset/images/test/255/369.jpg
#   inflating: dataset/images/test/255/370.jpg
#   inflating: dataset/images/test/255/371.jpg
#   inflating: dataset/images/test/255/372.jpg
#   inflating: dataset/images/test/255/373.jpg
#   inflating: dataset/images/test/255/374.jpg
#   inflating: dataset/images/test/255/375.jpg
#   inflating: dataset/images/test/255/376.jpg
#   inflating: dataset/images/test/255/377.jpg
#   inflating: dataset/images/test/255/378.jpg
#   inflating: dataset/images/test/255/379.jpg
#   inflating: dataset/images/test/255/380.jpg
#   inflating: dataset/images/test/255/381.jpg
#   inflating: dataset/images/test/255/382.jpg
#   inflating: dataset/images/test/255/383.jpg
#   inflating: dataset/images/test/255/384.jpg
#   inflating: dataset/images/test/255/385.jpg
#   inflating: dataset/images/test/255/386.jpg
#   inflating: dataset/images/test/255/387.jpg
#   inflating: dataset/images/test/255/388.jpg
#   inflating: dataset/images/test/255/389.jpg
#   inflating: dataset/images/test/255/390.jpg
#   inflating: dataset/images/test/255/391.jpg
#   inflating: dataset/images/test/255/392.jpg
#   inflating: dataset/images/test/255/393.jpg
#   inflating: dataset/images/test/255/394.jpg
#   inflating: dataset/images/test/255/395.jpg
#   inflating: dataset/images/test/255/396.jpg
#   inflating: dataset/images/test/255/397.jpg
#   inflating: dataset/images/test/255/398.jpg
#   inflating: dataset/images/test/255/399.jpg
#   inflating: dataset/images/test/255/400.jpg
#   inflating: dataset/images/test/255/401.jpg
#   inflating: dataset/images/test/255/402.jpg
#   inflating: dataset/images/test/255/403.jpg
#   inflating: dataset/images/test/255/404.jpg
#   inflating: dataset/images/test/255/405.jpg
#   inflating: dataset/images/test/255/406.jpg
#   inflating: dataset/images/test/255/407.jpg
#   inflating: dataset/val.csv
#   inflating: dataset/test.csv
#   inflating: dataset/deepseek_train.json
#   inflating: dataset/deepseek_val.json

# %%
from datasets import load_dataset

dataset_train = load_dataset("json", data_files="dataset/deepseek_train.json")["train"]
dataset_val   = load_dataset("json", data_files="dataset/deepseek_val.json")["train"]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
sample = dataset_val[0]
sample['messages'][0]['images'][0]  # for image
sample['messages'][1]['content']   # for OCR text
# Out:
# 'triệu'

# %%
# Save an image that will not be used during training for evaluation purposes
from PIL import Image

# Example: pick first sample in validation set
sample = dataset_val[0]
image_path = sample['messages'][0]['images'][0]  # path from your JSON
Image.open(image_path).save("your_image.jpg")

# %%
# prompt = "\nFree OCR. "
prompt = "\nFree OCR. "
image_file = 'your_image.jpg'
output_path = './output'
# infer(self, tokenizer, prompt='', image_file='', output_path = ' ', base_size = 1024, image_size = 640, crop_mode = True, test_compress = False, save_results = False):

# Tiny: base_size = 512, image_size = 512, crop_mode = False
# Small: base_size = 640, image_size = 640, crop_mode = False
# Base: base_size = 1024, image_size = 1024, crop_mode = False
# Large: base_size = 1280, image_size = 1280, crop_mode = False

# Gundam: base_size = 1024, image_size = 640, crop_mode = True

res = model.infer(tokenizer, prompt=prompt, image_file=image_file, output_path = output_path, base_size = 1024, image_size = 640, crop_mode=True, save_results = True, test_compress = False)
# Out:
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# \[\forall n \geq 0\]
# ===============save results:===============
# image: 0it [00:00, ?it/s]
# other: 0it [00:00, ?it/s]

# %% [markdown]
# <h3>Baseline Model Performance: 23% Character Error Rate (CER) for this sample !</h3>

# %% [markdown]
# # Let's finetune Deepseek-OCR !

# %% [markdown]
# We now add LoRA adapters for parameter efficient finetuning - this allows us to only efficiently train 1% of all parameters.
#
# **[NEW]** We also support finetuning ONLY the vision part of the model, or ONLY the language part. Or you can select both! You can also select to finetune the attention or the MLP layers!

# %%
from IPython.display import Image, display

display(Image(filename='your_image.jpg'))

# %%
model = FastVisionModel.get_peft_model(
    model,
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],

    r = 16,           # The larger, the higher the accuracy, but might overfit
    lora_alpha = 16,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
    # target_modules = "all-linear", # Optional now! Can specify a list if needed
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1487342198.py in <cell line: 0>()
# ----> 1 model = FastVisionModel.get_peft_model(
#       2     model,
#       3     target_modules=[
#       4         "q_proj",
#       5         "k_proj",
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/vision.py in get_peft_model(model, r, target_modules, lora_alpha, lora_dropout, bias, finetune_vision_layers, finetune_language_layers, finetune_attention_modules, finetune_mlp_modules, layers_to_transform, layers_pattern, use_gradient_checkpointing, random_state, max_seq_length, use_rslora, modules_to_save, init_lora_weights, loftq_config, task_type, temporary_location, qat_scheme, **kwargs)
#     946
#     947         if isinstance(model, PeftModelForCausalLM):
# --> 948             raise RuntimeError(
#     949                 "Unsloth: You already added LoRA adapters to your model!"
#     950             )
#
# RuntimeError: Unsloth: You already added LoRA adapters to your model!

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We'll be using a dataset for Persian OCR. The goal is to convert these images into a computer readable form - ie text. This can be very useful for digitizing Persian text.
#
# You can access the dataset [here](https://huggingface.co/datasets/hezarai/parsynth-ocr-200k).

# %% [markdown]
# To format the dataset, all vision finetuning tasks should be formatted as follows:
#
# ```python
# [
# { "role": "<|User|>",
#   "content": "",
#   "images": []
# },
# { "role": "<|Assistant|>",
#   "content": ""
# },
# ]
# ```

# %%
instruction = "\nFree OCR. "

def convert_to_conversation(sample):
    """Convert dataset sample to conversation format"""
    conversation = [
        {
            "role": "<|User|>",
            "content": instruction,
            "images": [sample['image']]
        },
        {
            "role": "<|Assistant|>",
            "content": sample["text"]
        },
    ]
    return {"messages": conversation}

# %% [markdown]
# Let's convert the dataset into the "correct" format for finetuning:

# %%
converted_train = dataset_train
converted_val   = dataset_val

# %% [markdown]
# We look at how the conversations are structured for the first example:

# %%
# @title Create datacollator

import torch
import math
from dataclasses import dataclass
from typing import Dict, List, Any, Tuple
from PIL import Image, ImageOps
from torch.nn.utils.rnn import pad_sequence
import io

from deepseek_ocr.modeling_deepseekocr import (
    format_messages,
    text_encode,
    BasicImageTransform,
    dynamic_preprocess,
)

@dataclass
class DeepSeekOCRDataCollator:
    """
    Args:
        tokenizer: Tokenizer
        model: Model
        image_size: Size for image patches (default: 640)
        base_size: Size for global view (default: 1024)
        crop_mode: Whether to use dynamic cropping for large images
        train_on_responses_only: If True, only train on assistant responses (mask user prompts)
    """
    tokenizer: Any
    model: Any
    image_size: int = 640
    base_size: int = 1024
    crop_mode: bool = True
    image_token_id: int = 128815
    train_on_responses_only: bool = True

    def __init__(
        self,
        tokenizer,
        model,
        image_size: int = 640,
        base_size: int = 1024,
        crop_mode: bool = True,
        train_on_responses_only: bool = True,
    ):
        self.tokenizer = tokenizer
        self.model = model
        self.image_size = image_size
        self.base_size = base_size
        self.crop_mode = crop_mode
        self.image_token_id = 128815
        self.dtype = model.dtype  # Get dtype from model
        self.train_on_responses_only = train_on_responses_only

        self.image_transform = BasicImageTransform(
            mean=(0.5, 0.5, 0.5),
            std=(0.5, 0.5, 0.5),
            normalize=True
        )
        self.patch_size = 16
        self.downsample_ratio = 4

        # Get BOS token ID from tokenizer
        if hasattr(tokenizer, 'bos_token_id') and tokenizer.bos_token_id is not None:
            self.bos_id = tokenizer.bos_token_id
        else:
            self.bos_id = 0
            print(f"Warning: tokenizer has no bos_token_id, using default: {self.bos_id}")

    def deserialize_image(self, image_data) -> Image.Image:
        """Convert image data (bytes dict or PIL Image) to PIL Image in RGB mode"""
        if isinstance(image_data, Image.Image):
            return image_data.convert("RGB")
        elif isinstance(image_data, dict) and 'bytes' in image_data:
            image_bytes = image_data['bytes']
            image = Image.open(io.BytesIO(image_bytes))
            return image.convert("RGB")
        else:
            raise ValueError(f"Unsupported image format: {type(image_data)}")

    def calculate_image_token_count(self, image: Image.Image, crop_ratio: Tuple[int, int]) -> int:
        """Calculate the number of tokens this image will generate"""
        num_queries = math.ceil((self.image_size // self.patch_size) / self.downsample_ratio)
        num_queries_base = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)

        width_crop_num, height_crop_num = crop_ratio

        if self.crop_mode:
            img_tokens = num_queries_base * num_queries_base + 1
            if width_crop_num > 1 or height_crop_num > 1:
                img_tokens += (num_queries * width_crop_num + 1) * (num_queries * height_crop_num)
        else:
            img_tokens = num_queries * num_queries + 1

        return img_tokens

    def process_image(self, image: Image.Image) -> Tuple[List, List, List, List, Tuple[int, int]]:
        """
        Process a single image based on crop_mode and size thresholds

        Returns:
            Tuple of (images_list, images_crop_list, images_spatial_crop, tokenized_image, crop_ratio)
        """
        images_list = []
        images_crop_list = []
        images_spatial_crop = []

        if self.crop_mode:
            # Determine crop ratio based on image size
            if image.size[0] <= 640 and image.size[1] <= 640:
                crop_ratio = (1, 1)
                images_crop_raw = []
            else:
                images_crop_raw, crop_ratio = dynamic_preprocess(
                    image, min_num=2, max_num=9,
                    image_size=self.image_size, use_thumbnail=False
                )

            # Process global view with padding
            global_view = ImageOps.pad(
                image, (self.base_size, self.base_size),
                color=tuple(int(x * 255) for x in self.image_transform.mean)
            )
            images_list.append(self.image_transform(global_view).to(self.dtype))

            width_crop_num, height_crop_num = crop_ratio
            images_spatial_crop.append([width_crop_num, height_crop_num])

            # Process local views (crops) if applicable
            if width_crop_num > 1 or height_crop_num > 1:
                for crop_img in images_crop_raw:
                    images_crop_list.append(
                        self.image_transform(crop_img).to(self.dtype)
                    )

            # Calculate image tokens
            num_queries = math.ceil((self.image_size // self.patch_size) / self.downsample_ratio)
            num_queries_base = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)

            tokenized_image = ([self.image_token_id] * num_queries_base + [self.image_token_id]) * num_queries_base
            tokenized_image += [self.image_token_id]

            if width_crop_num > 1 or height_crop_num > 1:
                tokenized_image += ([self.image_token_id] * (num_queries * width_crop_num) + [self.image_token_id]) * (
                    num_queries * height_crop_num)

        else:  # crop_mode = False
            crop_ratio = (1, 1)
            images_spatial_crop.append([1, 1])

            # For smaller base sizes, resize; for larger, pad
            if self.base_size <= 640:
                resized_image = image.resize((self.base_size, self.base_size), Image.LANCZOS)
                images_list.append(self.image_transform(resized_image).to(self.dtype))
            else:
                global_view = ImageOps.pad(
                    image, (self.base_size, self.base_size),
                    color=tuple(int(x * 255) for x in self.image_transform.mean)
                )
                images_list.append(self.image_transform(global_view).to(self.dtype))

            num_queries = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)
            tokenized_image = ([self.image_token_id] * num_queries + [self.image_token_id]) * num_queries
            tokenized_image += [self.image_token_id]

        return images_list, images_crop_list, images_spatial_crop, tokenized_image, crop_ratio

    def process_single_sample(self, messages: List[Dict]) -> Dict[str, Any]:
            """
            Process a single conversation into model inputs.
            """

            # --- 1. Setup ---
            images = []
            for message in messages:
                if "images" in message and message["images"]:
                    for img_data in message["images"]:
                        if img_data is not None:
                            pil_image = self.deserialize_image(img_data)
                            images.append(pil_image)

            if not images:
                raise ValueError("No images found in sample. Please ensure all samples contain images.")

            tokenized_str = []
            images_seq_mask = []
            images_list, images_crop_list, images_spatial_crop = [], [], []

            prompt_token_count = -1 # Index to start training
            assistant_started = False
            image_idx = 0

            # Add BOS token at the very beginning
            tokenized_str.append(self.bos_id)
            images_seq_mask.append(False)

            for message in messages:
                role = message["role"]
                content = message["content"]

                # Check if this is the assistant's turn
                if role == "<|Assistant|>":
                    if not assistant_started:
                        # This is the split point. All tokens added *so far*
                        # are part of the prompt.
                        prompt_token_count = len(tokenized_str)
                        assistant_started = True

                    # Append the EOS token string to the *end* of assistant content
                    content = f"{content.strip()} {self.tokenizer.eos_token}"

                # Split this message's content by the image token
                text_splits = content.split('')

                for i, text_sep in enumerate(text_splits):
                    # Tokenize the text part
                    tokenized_sep = text_encode(self.tokenizer, text_sep, bos=False, eos=False)
                    tokenized_str.extend(tokenized_sep)
                    images_seq_mask.extend([False] * len(tokenized_sep))

                    # If this text is followed by an  tag
                    if i < len(text_splits) - 1:
                        if image_idx >= len(images):
                            raise ValueError(
                                f"Data mismatch: Found '' token but no corresponding image."
                            )

                        # Process the image
                        image = images[image_idx]
                        img_list, crop_list, spatial_crop, tok_img, _ = self.process_image(image)

                        images_list.extend(img_list)
                        images_crop_list.extend(crop_list)
                        images_spatial_crop.extend(spatial_crop)

                        # Add image placeholder tokens
                        tokenized_str.extend(tok_img)
                        images_seq_mask.extend([True] * len(tok_img))

                        image_idx += 1 # Move to the next image

            # --- 3. Validation and Final Prep ---
            if image_idx != len(images):
                raise ValueError(
                    f"Data mismatch: Found {len(images)} images but only {image_idx} '' tokens were used."
                )

            # If we never found an assistant message, we're in a weird state
            # (e.g., user-only prompt). We mask everything.
            if not assistant_started:
                print("Warning: No assistant message found in sample. Masking all tokens.")
                prompt_token_count = len(tokenized_str)

            # Prepare image tensors
            images_ori = torch.stack(images_list, dim=0)
            images_spatial_crop_tensor = torch.tensor(images_spatial_crop, dtype=torch.long)

            if images_crop_list:
                images_crop = torch.stack(images_crop_list, dim=0)
            else:
                images_crop = torch.zeros((1, 3, self.base_size, self.base_size), dtype=self.dtype)

            return {
                "input_ids": torch.tensor(tokenized_str, dtype=torch.long),
                "images_seq_mask": torch.tensor(images_seq_mask, dtype=torch.bool),
                "images_ori": images_ori,
                "images_crop": images_crop,
                "images_spatial_crop": images_spatial_crop_tensor,
                "prompt_token_count": prompt_token_count, # This is now accurate
            }

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, torch.Tensor]:
        """Collate batch of samples"""
        batch_data = []

        # Process each sample
        for feature in features:
            try:
                processed = self.process_single_sample(feature['messages'])
                batch_data.append(processed)
            except Exception as e:
                print(f"Error processing sample: {e}")
                continue

        if not batch_data:
            raise ValueError("No valid samples in batch")

        # Extract lists
        input_ids_list = [item['input_ids'] for item in batch_data]
        images_seq_mask_list = [item['images_seq_mask'] for item in batch_data]
        prompt_token_counts = [item['prompt_token_count'] for item in batch_data]

        # Pad sequences
        input_ids = pad_sequence(input_ids_list, batch_first=True, padding_value=self.tokenizer.pad_token_id)
        images_seq_mask = pad_sequence(images_seq_mask_list, batch_first=True, padding_value=False)

        # Create labels
        labels = input_ids.clone()

        # Mask padding tokens
        labels[labels == self.tokenizer.pad_token_id] = -100

        # Mask image tokens (model shouldn't predict these)
        labels[images_seq_mask] = -100

        # Mask user prompt tokens when train_on_responses_only=True (only train on assistant responses)
        if self.train_on_responses_only:
            for idx, prompt_count in enumerate(prompt_token_counts):
                if prompt_count > 0:
                    labels[idx, :prompt_count] = -100

        # Create attention mask
        attention_mask = (input_ids != self.tokenizer.pad_token_id).long()

        # Prepare images batch (list of tuples)
        images_batch = []
        for item in batch_data:
            images_batch.append((item['images_crop'], item['images_ori']))

        # Stack spatial crop info
        images_spatial_crop = torch.cat([item['images_spatial_crop'] for item in batch_data], dim=0)

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels,
            "images": images_batch,
            "images_seq_mask": images_seq_mask,
            "images_spatial_crop": images_spatial_crop,
        }

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's train our model. We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!
#
# We use our new `DeepSeekOCRDataCollator` which will help in our vision finetuning setup.

# %%
from transformers import Trainer, TrainingArguments
from unsloth import is_bf16_supported
FastVisionModel.for_training(model) # Enable for training!
data_collator = DeepSeekOCRDataCollator(
    tokenizer=tokenizer,
    model = model,
    image_size=640,
    base_size=1024,
    crop_mode=True,
    train_on_responses_only=True,
)
trainer = Trainer(
    model = model,
    tokenizer = tokenizer,
    data_collator = data_collator, # Must use!
    train_dataset = converted_train,
    eval_dataset  = converted_val,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 60,
        # num_train_epochs = 1, # Set this instead of max_steps for full training runs
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.001,
        lr_scheduler_type = "linear",
        seed = 3407,
        fp16 = not is_bf16_supported(),  # Use fp16 if bf16 is not supported
        bf16 = is_bf16_supported(),  # Use bf16 if supported
        output_dir = "outputs",
        report_to = "none",     # For Weights and Biases
        dataloader_num_workers=2,
        # You MUST put the below items for vision finetuning:
        remove_unused_columns = False,
    ),
)
# Out:
# /tmp/ipython-input-701024634.py:12: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer._unsloth___init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 7.145 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 96,846 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 77,509,632 of 3,413,615,872 (2.27% trained)
# Error processing sample: Unsupported image format: <class 'str'>Error processing sample: Unsupported image format: <class 'str'>
#
# Error processing sample: Unsupported image format: <class 'str'>Error processing sample: Unsupported image format: <class 'str'>
#
# Error processing sample: Unsupported image format: <class 'str'>
# Error processing sample: Unsupported image format: <class 'str'>Error processing sample: Unsupported image format: <class 'str'>
#
# Error processing sample: Unsupported image format: <class 'str'>
# Error processing sample: Unsupported image format: <class 'str'>
# Error processing sample: Unsupported image format: <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-773422404.py in <cell line: 0>()
# ----> 1 trainer_stats = trainer.train()
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326                 hf_hub_utils.enable_progress_bars()
#    2327         else:
# -> 2328             return inner_training_loop(
#    2329                 args=args,
#    2330                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/compiler.py in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/loss_utils.py in _unsloth_get_batch_samples(self, epoch_iterator, num_batches, device, *args, **kwargs)
#     324     for _ in range(num_batches):
#     325         try:
# --> 326             batch_samples += [next(epoch_iterator)]
#     327         except StopIteration:
#     328             break
#
# /usr/local/lib/python3.12/dist-packages/accelerate/data_loader.py in __iter__(self)
#     565         # We iterate one batch ahead to check when we are at the end
#     566         try:
# --> 567             current_batch = next(dataloader_iter)
#     568         except StopIteration:
#     569             self.end()
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1504                 worker_id = self._task_info.pop(idx)[0]
#    1505                 self._rcvd_idx += 1
# -> 1506                 return self._process_data(data, worker_id)
#    1507
#    1508     def _try_put_index(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data, worker_idx)
#    1539         self._try_put_index()
#    1540         if isinstance(data, ExceptionWrapper):
# -> 1541             data.reraise()
#    1542         return data
#    1543
#
# /usr/local/lib/python3.12/dist-packages/torch/_utils.py in reraise(self)
#     767             # be constructed, don't try to instantiate since we don't know how to
#     768             raise RuntimeError(msg) from None
# --> 769         raise exception
#     770
#     771
#
# ValueError: Caught ValueError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/worker.py", line 349, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2895700843.py", line 286, in __call__
#     raise ValueError("No valid samples in batch")
# ValueError: No valid samples in batch

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model!

# %%
prompt = "\nFree OCR. "
image_file = 'your_image.jpg'
output_path = './output'

# Tiny: base_size = 512, image_size = 512, crop_mode = False
# Small: base_size = 640, image_size = 640, crop_mode = False
# Base: base_size = 1024, image_size = 1024, crop_mode = False
# Large: base_size = 1280, image_size = 1280, crop_mode = False

# Gundam: base_size = 1024, image_size = 640, crop_mode = True

res = model.infer(tokenizer, prompt=prompt, image_file=image_file,
    output_path = output_path,
    image_size=640,
    base_size=1024,
    crop_mode=True,
    save_results = True,
    test_compress = False)
# Out:
# ['', '\nFree OCR.']
# انضباطم نشدم حقیقتن باورم نمیشد
# ===============save results:===============
# image: 0it [00:00, ?it/s]
# other: 0it [00:00, ?it/s]

# %% [markdown]
# With only 60 steps, we dramatically improved the transcription quality. The Character Error Rate (CER) on this single sample dropped from 23% to 6%, a 74% relative reduction!
#
# | Type | OCR |
# | :--- | :--- |
# | **Baseline (Pre-Finetune)** | `انضباطم نندم حقيقتن باورم نميتند` |
# | **Finetuned (60 steps)** | `انضباطم نشدم حقیقتن باورم نمیشد` |
# | **Ground Truth** | `انضباطمم شدم حقیقتن باورم نمیشد` |

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastVisionModel
    model, tokenizer = FastVisionModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = False, # Use 4bit to reduce memory use. False for 16bit LoRA.
        auto_model = AutoModel,
        trust_remote_code=True,
        unsloth_force_compile=True,
        use_gradient_checkpointing = "unsloth", # True or "unsloth" for long context
    )
    FastVisionModel.for_inference(model) # Enable for inference!

prompt = "\nFree OCR. "
image_file = 'your_image.jpg'
output_path = './output'

# Tiny: base_size = 512, image_size = 512, crop_mode = False
# Small: base_size = 640, image_size = 640, crop_mode = False
# Base: base_size = 1024, image_size = 1024, crop_mode = False
# Large: base_size = 1280, image_size = 1280, crop_mode = False

# Gundam: base_size = 1024, image_size = 640, crop_mode = True

res = model.infer(tokenizer, prompt=prompt, image_file=image_file,
    output_path = output_path,
    image_size=640,
    base_size=1024,
    crop_mode=True,
    save_results = True,
    test_compress = False)

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Select ONLY 1 to save! (Both not needed!)

# Save locally to 16bit
if False: model.save_pretrained_merged("unsloth_finetune", tokenizer,)

# To export and save to your Hugging Face account
if False: model.push_to_hub_merged("YOUR_USERNAME/unsloth_finetune", tokenizer, token = "PUT_HERE")

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   This notebook and all Unsloth notebooks are licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme)
# </div>
